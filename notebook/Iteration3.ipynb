# %%
import pandas as pd

# %%
df = pd.read_csv("../data/trees.csv", sep=';', low_memory=False)

# %%
df
# Out:
#        elem_point_id      code      nom genre  genre_desc categorie  \
# 0            27452.0  ESP29627  AR29627   VEG  VEGETATION     ESP01
# 1            27458.0  ESP29628  AR29628   VEG  VEGETATION     ESP01
# 2            27461.0  ESP29629  AR29629   VEG  VEGETATION     ESP01
# 3            27467.0  ESP29630  AR29630   VEG  VEGETATION     ESP01
# 4            27470.0  ESP29631  AR29631   VEG  VEGETATION     ESP01
# ...              ...       ...      ...   ...         ...       ...
# 31821        27517.0  ESP27738  AR27738   VEG  VEGETATION     ESP01
# 31822        27519.0  ESP27739  AR27739   VEG  VEGETATION     ESP01
# 31823        27521.0  ESP27740  AR27740   VEG  VEGETATION     ESP01
# 31824        27523.0  ESP27741  AR27741   VEG  VEGETATION     ESP01
# 31825        27525.0  ESP27742  AR27742   VEG  VEGETATION     ESP01
#
#       categorie_desc sous_categorie      sous_categorie_desc code_parent  ...  \
# ...

# %%
df.columns
# Out:
# Index(['elem_point_id', 'code', 'nom', 'genre', 'genre_desc', 'categorie',
#        'categorie_desc', 'sous_categorie', 'sous_categorie_desc',
#        'code_parent', 'code_parent_desc', 'adr_secteur', 'bien_reference',
#        'genre_bota', 'espece', 'variete', 'stadededeveloppement', 'equipe',
#        'remarques', 'anneedeplantation', 'raisondeplantation',
#        'traitementchenilles', 'courrier', 'identifiantplu',
#        'typeimplantationplu', 'intituleprotectionplu', 'anneeabattage',
#        'essouchement', 'diametrearbre', 'causeabattage', 'collectivite',
#        'stationmetro', 'hauteurarbre', 'portarbre', 'structure', 'forme',
#        'typenature', 'geo_point_2d'],
#       dtype='object')

# %%
min(df["anneedeplantation"])
# Out:
# 1900.0

# %%
max(df["anneedeplantation"])
# Out:
# 2022.0

# %%
df[0:2]
# Out:
#    elem_point_id      code      nom genre  genre_desc categorie  \
# 0        27452.0  ESP29627  AR29627   VEG  VEGETATION     ESP01
# 1        27458.0  ESP29628  AR29628   VEG  VEGETATION     ESP01
#
#   categorie_desc sous_categorie      sous_categorie_desc code_parent  ...  \
# 0          Arbre         ESP174  Arbre d'espaces ouverts      ESP991  ...
# 1          Arbre         ESP174  Arbre d'espaces ouverts       ESP22  ...
#
#   diametrearbre  causeabattage       collectivite stationmetro  \
# 0           NaN            NaN  Ville de Grenoble          NaN
# 1           NaN            NaN  Ville de Grenoble          NaN
#
#      hauteurarbre portarbre          structure  forme typenature  \
# 0  de 10 m à 20 m     Libre  Ville de Grenoble   Tige      Libre
# 1    Plus de 20 m     Libre  Ville de Grenoble    NaN      Libre
#
#                           geo_point_2d
# 0  45.18599541005583,5.736390702744254
# 1  45.18535720117796,5.737112737684537
#
# [2 rows x 38 columns]

# %%
df.loc[df['anneedeplantation'] == 2022, 'anneedeplantation']
# Out:
# 361      2022.0
# 362      2022.0
# 366      2022.0
# 367      2022.0
# 368      2022.0
#           ...
# 23713    2022.0
# 23714    2022.0
# 23821    2022.0
# 23822    2022.0
# 23823    2022.0
# Name: anneedeplantation, Length: 215, dtype: float64

# %%
df.columns
# Out:
# Index(['elem_point_id', 'code', 'nom', 'genre', 'genre_desc', 'categorie',
#        'categorie_desc', 'sous_categorie', 'sous_categorie_desc',
#        'code_parent', 'code_parent_desc', 'adr_secteur', 'bien_reference',
#        'genre_bota', 'espece', 'variete', 'stadededeveloppement', 'equipe',
#        'remarques', 'anneedeplantation', 'raisondeplantation',
#        'traitementchenilles', 'courrier', 'identifiantplu',
#        'typeimplantationplu', 'intituleprotectionplu', 'anneeabattage',
#        'essouchement', 'diametrearbre', 'causeabattage', 'collectivite',
#        'stationmetro', 'hauteurarbre', 'portarbre', 'structure', 'forme',
#        'typenature', 'geo_point_2d'],
#       dtype='object')

# %%
df.head(25)
df['anneedeplantation'].values
# Out:
# array([1965., 1965., 1965., ..., 1960., 1979., 1981.])

# %%
df['anneedeplantation']
# Out:
# 0        1965.0
# 1        1965.0
# 2        1965.0
# 3        1965.0
# 4        1965.0
#           ...
# 31821    1970.0
# 31822    1997.0
# 31823    1960.0
# 31824    1979.0
# 31825    1981.0
# Name: anneedeplantation, Length: 31826, dtype: float64

# %%
df.iloc[0:2,1]
# Out:
# 0    ESP29627
# 1    ESP29628
# Name: code, dtype: object

# %%
df.iloc[25:28, [2,13]]
# Out:
#         nom genre_bota
# 25  AR29668       Acer
# 26  AR29669   Platanus
# 27  AR29670   Platanus

# %%
df['anneedeplantation']
# Out:
# 0        1965.0
# 1        1965.0
# 2        1965.0
# 3        1965.0
# 4        1965.0
#           ...
# 31821    1970.0
# 31822    1997.0
# 31823    1960.0
# 31824    1979.0
# 31825    1981.0
# Name: anneedeplantation, Length: 31826, dtype: float64

# %%
df[0:5]
# Out:
#    elem_point_id      code      nom genre  genre_desc categorie  \
# 0        27452.0  ESP29627  AR29627   VEG  VEGETATION     ESP01
# 1        27458.0  ESP29628  AR29628   VEG  VEGETATION     ESP01
# 2        27461.0  ESP29629  AR29629   VEG  VEGETATION     ESP01
# 3        27467.0  ESP29630  AR29630   VEG  VEGETATION     ESP01
# 4        27470.0  ESP29631  AR29631   VEG  VEGETATION     ESP01
#
#   categorie_desc sous_categorie      sous_categorie_desc code_parent  ...  \
# 0          Arbre         ESP174  Arbre d'espaces ouverts      ESP991  ...
# 1          Arbre         ESP174  Arbre d'espaces ouverts       ESP22  ...
# 2          Arbre         ESP174  Arbre d'espaces ouverts       ESP22  ...
# 3          Arbre         ESP174  Arbre d'espaces ouverts      ESP843  ...
# 4          Arbre         ESP174  Arbre d'espaces ouverts      ESP614  ...
#
#   diametrearbre  causeabattage       collectivite stationmetro  \
# 0           NaN            NaN  Ville de Grenoble          NaN
# ...

# %%
df[['anneedeplantation', 'genre_bota']]
# Out:
#        anneedeplantation genre_bota
# 0                 1965.0     Ginkgo
# 1                 1965.0   Platanus
# 2                 1965.0      Morus
# 3                 1965.0      Taxus
# 4                 1965.0       Acer
# ...                  ...        ...
# 31821             1970.0     Prunus
# 31822             1997.0      Tilia
# 31823             1960.0   Platanus
# 31824             1979.0    Catalpa
# 31825             1981.0      Tilia
#
# [31826 rows x 2 columns]

# %%
df.loc[df['anneedeplantation'] == 1981, 'genre_bota']
# Out:
# 29           Acer
# 40         Cercis
# 203       Populus
# 204          Acer
# 352         Tilia
#            ...
# 31341       Pinus
# 31357    Carpinus
# 31554     Sophora
# 31781       Tilia
# 31825       Tilia
# Name: genre_bota, Length: 580, dtype: object

# %%
arbre_par_an = df['anneedeplantation'].value_counts()
arbre_par_an
# Out:
# anneedeplantation
# 1975.0    3452
# 2001.0    1449
# 1980.0    1359
# 1970.0    1293
# 2015.0    1004
#           ...
# 1900.0      25
# 1959.0      16
# 1924.0      11
# 1964.0       6
# 2021.0       5
# Name: count, Length: 66, dtype: int64

# %%
df['anneedeplantation'].value_counts().mean()
# Out:
# 451.93939393939394

# %%
arbre_par_an.mean()
# Out:
# 451.93939393939394

# %%
liste_tuple = [(annee , valeur) for annee , valeur in arbre_par_an.items()]
liste_tuple
# Out:
# [(1975.0, 3452),
#  (2001.0, 1449),
#  (1980.0, 1359),
#  (1970.0, 1293),
#  (2015.0, 1004),
#  (2018.0, 871),
#  (1976.0, 871),
#  (2014.0, 835),
#  (1985.0, 830),
#  (1978.0, 822),
#  (1965.0, 718),
#  (1995.0, 698),
#  (1960.0, 696),
#  (1987.0, 678),
#  (1984.0, 639),
#  (2009.0, 630),
#  (2017.0, 619),
#  (1977.0, 596),
#  (1981.0, 580),
#  (2006.0, 570),
#  (1999.0, 552),
#  (2016.0, 520),
#  (2011.0, 484),
#  (2010.0, 445),
#  (2000.0, 410),
#  (1950.0, 397),
#  (2005.0, 375),
#  (2019.0, 355),
#  (1982.0, 340),
#  (1996.0, 337),
#  (2004.0, 331),
#  (2003.0, 327),
#  (2002.0, 315),
#  (1979.0, 307),
#  (2013.0, 306),
#  (1969.0, 303),
#  (2012.0, 298),
#  (1989.0, 290),
#  (1972.0, 289),
#  (1983.0, 279),
#  (1974.0, 277),
#  (1994.0, 238),
#  (1990.0, 237),
#  (1997.0, 228),
#  (1988.0, 224),
#  (2022.0, 215),
#  (1992.0, 213),
#  (1986.0, 207),
#  (2008.0, 207),
#  (1998.0, 198),
#  (2020.0, 172),
#  (2007.0, 134),
#  (1993.0, 132),
#  (1991.0, 132),
#  (1955.0, 113),
# ...

# %%
arbre_par_an.mean()
# Out:
# 451.93939393939394

# %%
df['anneedeplantation'].value_counts()[1981]
# Out:
# 580

# %%
#Moyenne d'arbres plantés par année
df['anneedeplantation'].value_counts().mean()
# Out:
# 451.93939393939394

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31826 entries, 0 to 31825
# Data columns (total 38 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   elem_point_id          31817 non-null  float64
#  1   code                   31826 non-null  object
#  2   nom                    31826 non-null  object
#  3   genre                  31826 non-null  object
#  4   genre_desc             31826 non-null  object
#  5   categorie              31817 non-null  object
#  6   categorie_desc         31817 non-null  object
#  7   sous_categorie         31817 non-null  object
#  8   sous_categorie_desc    31817 non-null  object
#  9   code_parent            31817 non-null  object
#  10  code_parent_desc       31817 non-null  object
#  11  adr_secteur            31808 non-null  float64
#  12  bien_reference         31808 non-null  object
#  13  genre_bota             31001 non-null  object
# ...

# %%
#nombre d'arbres pour lesquels l'année de plantation n'est pas référencée
df['anneedeplantation'].isna().sum()
# Out:
# 1998

# %%
df['genre_bota'].isna().sum()
# Out:
# 825

# %%
df['anneedeplantation'].fillna(0, inplace = True)
df['anneedeplantation'].astype(int)
# Out:
# 0        1965
# 1        1965
# 2        1965
# 3        1965
# 4        1965
#          ...
# 31821    1970
# 31822    1997
# 31823    1960
# 31824    1979
# 31825    1981
# Name: anneedeplantation, Length: 31826, dtype: int64

# %%
df['anneedeplantation'].value_counts()[0]
# Out:
# 1998

# %%
df.query("anneedeplantation == 1995")
# Out:
#        elem_point_id      code      nom genre  genre_desc categorie  \
# 12           14336.0  ESP29645  AR29645   VEG  VEGETATION     ESP01
# 13           14340.0  ESP29646  AR29646   VEG  VEGETATION     ESP01
# 97           23572.0  ESP29862  AR29862   VEG  VEGETATION     ESP01
# 115          21131.0  ESP29883  AR29883   VEG  VEGETATION     ESP01
# 214           1178.0  ESP29428  AR29428   VEG  VEGETATION     ESP01
# ...              ...       ...      ...   ...         ...       ...
# 31676        28484.0  ESP28375  AR28375   VEG  VEGETATION     ESP01
# 31677        28488.0  ESP28376  AR28376   VEG  VEGETATION     ESP01
# 31764        24766.0  ESP28401  AR28401   VEG  VEGETATION     ESP01
# 31771        24859.0  ESP28408  AR28408   VEG  VEGETATION     ESP01
# 31772        24861.0  ESP28409  AR28409   VEG  VEGETATION     ESP01
#
#       categorie_desc sous_categorie      sous_categorie_desc code_parent  ...  \
# ...

# %%
df.query("anneedeplantation == 1995")
# Out:
#        elem_point_id      code      nom genre  genre_desc categorie  \
# 12           14336.0  ESP29645  AR29645   VEG  VEGETATION     ESP01
# 13           14340.0  ESP29646  AR29646   VEG  VEGETATION     ESP01
# 97           23572.0  ESP29862  AR29862   VEG  VEGETATION     ESP01
# 115          21131.0  ESP29883  AR29883   VEG  VEGETATION     ESP01
# 214           1178.0  ESP29428  AR29428   VEG  VEGETATION     ESP01
# ...              ...       ...      ...   ...         ...       ...
# 31676        28484.0  ESP28375  AR28375   VEG  VEGETATION     ESP01
# 31677        28488.0  ESP28376  AR28376   VEG  VEGETATION     ESP01
# 31764        24766.0  ESP28401  AR28401   VEG  VEGETATION     ESP01
# 31771        24859.0  ESP28408  AR28408   VEG  VEGETATION     ESP01
# 31772        24861.0  ESP28409  AR28409   VEG  VEGETATION     ESP01
#
#       categorie_desc sous_categorie      sous_categorie_desc code_parent  ...  \
# ...

# %%
df[['genre_bota', 'espece']].drop_duplicates()
# Out:
#           genre_bota       espece
# 0             Ginkgo       biloba
# 1           Platanus   acerifolia
# 2              Morus        nigra
# 3              Taxus      baccata
# 4               Acer  platanoides
# ...              ...          ...
# 30106           Olea          NaN
# 30883      Sterculia      foetida
# 30917        Quercus  salicifolia
# 30988          Pinus      strobus
# 31687  Chamaecyparis     pisifera
#
# [457 rows x 2 columns]

# %%
df[['genre_bota']].value_counts()
# Out:
# genre_bota
# Acer          5047
# Platanus      4453
# Pinus         1923
# Tilia         1741
# Fraxinus      1528
#               ...
# Staphylea        1
# Rhamnus          1
# Sorbopyrus       1
# Castanea         1
# Poncinos         1
# Name: count, Length: 116, dtype: int64

# %%
df[['genre_bota', 'espece']].value_counts()
# Out:
# genre_bota  espece
# Platanus    acerifolia        3757
# Acer        pseudoplatanus    1276
# Pinus       nigra             1227
# Carpinus    betulus           1151
# Acer        platanoides        985
#                               ...
# Malus       hybride              1
#             ioenis               1
# Quercus     macrolepis           1
#             macrocarpa           1
# inconnu     alba                 1
# Name: count, Length: 400, dtype: int64

# %%
proportion_genre = df[['genre_bota']].value_counts()
proportion_genre = proportion_genre.apply(lambda x : x*100/31826)
proportion_genre
# Out:
# genre_bota
# Acer          15.858103
# Platanus      13.991705
# Pinus          6.042230
# Tilia          5.470370
# Fraxinus       4.801106
#                 ...
# Staphylea      0.003142
# Rhamnus        0.003142
# Sorbopyrus     0.003142
# Castanea       0.003142
# Poncinos       0.003142
# Name: count, Length: 116, dtype: float64

# %%
df.to_csv('../data/trees2.csv', index=False, sep=';', low_memory=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df.to_csv('../data/trees2.csv', index=False, sep=';', low_memory=False)
#
# TypeError: NDFrame.to_csv() got an unexpected keyword argument 'low_memory'
