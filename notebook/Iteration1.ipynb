# %%
import csv
with open('../data/trees.csv', newline='') as f:
    reader=csv.reader(f, delimiter=';')
    data=list(reader)

# %%
data
# Out:
# [['\ufeffelem_point_id',
#   'code',
#   'nom',
#   'genre',
#   'genre_desc',
#   'categorie',
#   'categorie_desc',
#   'sous_categorie',
#   'sous_categorie_desc',
#   'code_parent',
#   'code_parent_desc',
#   'adr_secteur',
#   'bien_reference',
#   'genre_bota',
#   'espece',
#   'variete',
#   'stadededeveloppement',
#   'equipe',
#   'remarques',
#   'anneedeplantation',
#   'raisondeplantation',
#   'traitementchenilles',
#   'courrier',
#   'identifiantplu',
#   'typeimplantationplu',
#   'intituleprotectionplu',
#   'anneeabattage',
#   'essouchement',
#   'diametrearbre',
#   'causeabattage',
#   'collectivite',
#   'stationmetro',
#   'hauteurarbre',
#   'portarbre',
#   'structure',
#   'forme',
#   'typenature',
#   'geo_point_2d'],
#  ['27452',
#   'ESP29627',
#   'AR29627',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP991',
#   'Prc Mis dans vivaces Mairie',
#   '5',
#   'AR29627',
#   'Ginkgo',
# ...

# %%
data[0:1]
# Out:
# [['\ufeffelem_point_id',
#   'code',
#   'nom',
#   'genre',
#   'genre_desc',
#   'categorie',
#   'categorie_desc',
#   'sous_categorie',
#   'sous_categorie_desc',
#   'code_parent',
#   'code_parent_desc',
#   'adr_secteur',
#   'bien_reference',
#   'genre_bota',
#   'espece',
#   'variete',
#   'stadededeveloppement',
#   'equipe',
#   'remarques',
#   'anneedeplantation',
#   'raisondeplantation',
#   'traitementchenilles',
#   'courrier',
#   'identifiantplu',
#   'typeimplantationplu',
#   'intituleprotectionplu',
#   'anneeabattage',
#   'essouchement',
#   'diametrearbre',
#   'causeabattage',
#   'collectivite',
#   'stationmetro',
#   'hauteurarbre',
#   'portarbre',
#   'structure',
#   'forme',
#   'typenature',
#   'geo_point_2d']]

# %%
for row in data[:2]:
    print()
# Out:
# [1]
# [1]

# %%
for ligne in data[:5]:
    print(ligne[:3])
    print('\n')
# Out:
# ['\ufeffelem_point_id', 'code', 'nom']
#
#
# ['27452', 'ESP29627', 'AR29627']
#
#
# ['27458', 'ESP29628', 'AR29628']
#
#
# ['27461', 'ESP29629', 'AR29629']
#
#
# ['27467', 'ESP29630', 'AR29630']

# %%
for ligne in data[:5]:
    print(ligne[19])
# Out:
# anneedeplantation
# 1965
# 1965
# 1965
# 1965

# %%
data[0, 1][1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 data[0, 1][1]
#
# TypeError: list indices must be integers or slices, not tuple

# %%
data[0,1][1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 data[0,1][1]
#
# TypeError: list indices must be integers or slices, not tuple

# %%
for ligne Data[:1]:
    print(ligne[1])
# Out:
#   Cell In[18], line 1
#     for ligne Data[1]:
#               ^
# SyntaxError: invalid syntax

# %%
for ligne Data[:1]:
    print(ligne[1])
# Out:
#   Cell In[20], line 1
#     for ligne Data[:1]:
#               ^
# SyntaxError: invalid syntax

# %%
for ligne in Data[:1]:
    print(ligne[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 for ligne in Data[:1]:
#       2     print(ligne[1])
#
# NameError: name 'Data' is not defined

# %%
for ligne in data[1:3]:
    if (ligne) in > 1:
    print(ligne[1])
# Out:
#   Cell In[28], line 2
#     if (ligne) in > 1:
#                   ^
# SyntaxError: invalid syntax

# %%
for ligne in data[ :5]:
    print(ligne[1])
# Out:
#   Cell In[30], line 1
#     for ligne in data[ :5]
#                           ^
# SyntaxError: expected ':'

# %%
for ligne in data[ :5]:
    print(ligne[1])
# Out:
# code
# ESP29627
# ESP29628
# ESP29629
# ESP29630

# %%
for ligne in data[ :3]:
    print(ligne[1])
# Out:
# code
# ESP29627
# ESP29628

# %%
liste_annees=[]
for ligne in data[1:]:
    liste_annees.append(ligne[19])
# Out:
# 1965
# 1965
# 1965
# 1965
# 1965
# 2006
# 1965
# 1965
# 1965
# 1965
# 1965
# 2009
# 1995
# 1995
# 1979
# 1985
# 1976
# 1976
# 1975
# 1985
# 1976
# 1976
# 1975
# 1975
# 1975
# 1976
# 1976
# 1985
# 1985
# 1981
# 1974
# 1976
# 1976
# 2008
# 2008
# 1985
# 1985
# 1976
# 1976
# 1985
# 1981
# 1999
# 1965
# 1980
# 1970
# 1970
# 1984
# 1984
# 1969
# 1969
# 1979
# 1976
# 1970
# 2002
# 1984
# 1984
# 2001
# 1977
# 2006
# 2006
# 1960
# 1971
# 2001
# 2009
# 1970
# 2002
# 1984
# 1969
# 1980
# 2009
# 1978
# 1978
# 1998
# 1978
# 1977
# 2001
# 1975
# 1975
# 1983
# 1975
# 1975
# 2001
# 1975
# 1975
# 1992
# 1980
# 2001
# 1985
# 1977
# 1980
# 2001
# 1980
# 1975
# 2006
# 2001
# 1991
# 2003
# 1995
# 1975
# 2011
# 2009
# 1975
# 1973
# 1998
# 2010
# 1965
# 1978
# 1980
# 1975
# 1975
# 1975
# 1975
# 1997
# 2001
# 2013
# 1995
# 1970
# 1970
# 1975
# 1975
# 1980
# 2001
# 1979
# 2004
# 2004
# 2004
# 1978
# 1978
# 1978
# 1975
# 1975
# 2001
# 1975
# 1975
# 1971
# 1960
# 1994
# 1980
# 1978
# 1994
# 1999
# 1999
# ...

# %%
liste_annees
# Out:
# ['1965',
#  '1965',
#  '1965',
#  '1965',
#  '1965',
#  '2006',
#  '1965',
#  '1965',
#  '1965',
#  '1965',
#  '1965',
#  '2009',
#  '1995',
#  '1995',
#  '1979',
#  '1985',
#  '1976',
#  '1976',
#  '1975',
#  '1985',
#  '1976',
#  '1976',
#  '1975',
#  '1975',
#  '1975',
#  '1976',
#  '1976',
#  '1985',
#  '1985',
#  '1981',
#  '1974',
#  '1976',
#  '1976',
#  '2008',
#  '2008',
#  '1985',
#  '1985',
#  '1976',
#  '1976',
#  '1985',
#  '1981',
#  '1999',
#  '1965',
#  '1980',
#  '1970',
#  '1970',
#  '1984',
#  '1984',
#  '1969',
#  '1969',
#  '1979',
#  '1976',
#  '1970',
#  '2002',
#  '1984',
#  '1984',
#  '2001',
#  '1977',
#  '2006',
#  '2006',
#  '1960',
#  '1971',
#  '2001',
#  '2009',
#  '1970',
#  '2002',
#  '1984',
#  '1969',
#  '1980',
#  '2009',
#  '1978',
#  '1978',
#  '1998',
#  '1978',
#  '1977',
#  '2001',
#  '1975',
#  '1975',
#  '1983',
#  '1975',
#  '1975',
#  '2001',
#  '1975',
#  '1975',
#  '1992',
#  '1980',
#  '2001',
#  '1985',
#  '1977',
#  '1980',
# ...

# %%
liste_annees[1:50]
# Out:
# ['1965',
#  '1965',
#  '1965',
#  '1965',
#  '2006',
#  '1965',
#  '1965',
#  '1965',
#  '1965',
#  '1965',
#  '2009',
#  '1995',
#  '1995',
#  '1979',
#  '1985',
#  '1976',
#  '1976',
#  '1975',
#  '1985',
#  '1976',
#  '1976',
#  '1975',
#  '1975',
#  '1975',
#  '1976',
#  '1976',
#  '1985',
#  '1985',
#  '1981',
#  '1974',
#  '1976',
#  '1976',
#  '2008',
#  '2008',
#  '1985',
#  '1985',
#  '1976',
#  '1976',
#  '1985',
#  '1981',
#  '1999',
#  '1965',
#  '1980',
#  '1970',
#  '1970',
#  '1984',
#  '1984',
#  '1969',
#  '1969']

# %%
liste_annees[-50:]
# Out:
# ['2001',
#  '2001',
#  '1965',
#  '2010',
#  '1965',
#  '1981',
#  '1965',
#  '1975',
#  '2006',
#  '2001',
#  '2001',
#  '1975',
#  '1975',
#  '1977',
#  '2001',
#  '2001',
#  '1975',
#  '1978',
#  '1978',
#  '1998',
#  '1982',
#  '2001',
#  '1994',
#  '2011',
#  '2009',
#  '2006',
#  '2006',
#  '1975',
#  '2011',
#  '2006',
#  '1970',
#  '1965',
#  '1965',
#  '1965',
#  '1965',
#  '2006',
#  '1982',
#  '2006',
#  '1955',
#  '1965',
#  '1950',
#  '1965',
#  '2006',
#  '1965',
#  '1965',
#  '1970',
#  '1997',
#  '1960',
#  '1979',
#  '1981']

# %%
len(data)
# Out:
# 31827

# %%
nombre_1981=0
for ligne in data:
    if ligne[19]=="1981":
        nombre_1981+=1

print(nombre_1981)
# Out:
# 580
